# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Replace 'dataset_url' with your actual dataset link
dataset_url = '/content/advertising.csv'

# 1. Load the data into a pandas DataFrame
df = pd.read_csv(dataset_url)

# 2. Explore and preprocess the data
print(df.head())
print(df.describe())

# Assuming the dataset columns are similar to the sample dataset provided:
# 'TV', 'Radio', 'Newspaper', 'Sales'
# If the column names are different, you need to update them accordingly.

# 3. Split the data into training and testing sets
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 4. Train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# 5. Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

# 6. Make predictions
predictions = model.predict(X_test)
print("Predictions:", predictions)

# Plotting the results
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Sales")
plt.show()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000
# Mean Squared Error: 2.541624036229147
# R-squared: 0.9091484341849799
# Predictions: [17.15991908 20.53369503 23.68914396  9.5191455  21.60736836 12.78101318
#  21.08636345  8.76054246 17.11499951 16.68789636  8.97584663  8.57645026
# ...

# %%
import pandas as pd

# Replace 'dataset_url' with your actual dataset link
dataset_url = '/content/advertising.csv'

# Load the data into a pandas DataFrame
df = pd.read_csv("/content/advertising.csv")

# Display first few rows and summary statistics of the data
print(df.head())
print(df.describe())
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
import matplotlib.pyplot as plt

# Scatter plots to visualize relationships
plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.scatter(df['TV'], df['Sales'], color='blue')
plt.title('TV vs Sales')
plt.xlabel('TV Advertising Spend')
plt.ylabel('Sales')

plt.subplot(1, 3, 2)
plt.scatter(df['Radio'], df['Sales'], color='red')
plt.title('Radio vs Sales')
plt.xlabel('Radio Advertising Spend')
plt.ylabel('Sales')

plt.subplot(1, 3, 3)
plt.scatter(df['Newspaper'], df['Sales'], color='green')
plt.title('Newspaper vs Sales')
plt.xlabel('Newspaper Advertising Spend')
plt.ylabel('Sales')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Box plots to visualize distribution and outliers
plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
sns.boxplot(y=df['TV'])
plt.title('Box plot of TV Advertising Spend')

plt.subplot(1, 3, 2)
sns.boxplot(y=df['Radio'])
plt.title('Box plot of Radio Advertising Spend')

plt.subplot(1, 3, 3)
sns.boxplot(y=df['Newspaper'])
plt.title('Box plot of Newspaper Advertising Spend')

plt.tight_layout()
plt.show()

# %%
# Heatmap to visualize correlations
plt.figure(figsize=(8, 6))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Split the data into training and testing sets
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 2.541624036229147
# R-squared: 0.9091484341849799

# %%
# Plotting the actual vs predicted sales
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='purple')
plt.plot([y.min(), y.max()], [y.min(), y.max()], '--', color='red')
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Sales")
plt.show()

# %%
# Plotting residuals
residuals = y_test - y_pred
plt.figure(figsize=(8, 6))
sns.histplot(residuals, kde=True, color='orange')
plt.title("Residuals Distribution")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.show()
